# %% [markdown]
# <a href="https://colab.research.google.com/github/Urbinav005/Urbina-Avitia-Rodolfo-structured-programming/blob/main/lab2_worksheet_urbina_avitia_rodolfo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
CODE 1

# %%
def multiply(a, b):
   return a * b
print(multiply(3,4))

# %% [markdown]
# CODE 2

# %%
counter = 0
for i in range(4):
    counter = counter + 1
print(counter)

# %% [markdown]
# CODE 3

# %%
age = int(input("Enter your age: "))
if age >= 18
    print("Adult")

# %% [markdown]
# CODE 4

# %%
a = 3
b = 4

temp = a
a = b
b = temp
print(a)
print(b)

# %% [markdown]
# URBINA AVITIA RODOLFO 3A BIS
